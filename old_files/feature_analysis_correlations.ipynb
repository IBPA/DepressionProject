# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='whitegrid', font_scale = 1.5)
# load data
correlations = pd.read_csv('./output/vars_sorted.csv')

# %%
#correlations.dtypes
correlations = correlations[correlations.Diff_corr_and_corr_imp != '#DIV/0!']
correlations.Diff_corr_and_corr_imp = correlations.Diff_corr_and_corr_imp.astype('float')
correlations
# Out:
#              features                                        description  \
# 0        12-18-dep-yn  SMFQ depression score above cutoff at any poin...
# 1        fddp130_120m      Depression Score at Focus 10 assessment: F10+
# 2           sa013_90m  A1d: Teacher's rating of child for age - gener...
# 3         ku710b_108m      DV: SDQ - Total difficulties score (prorated)
# 4           sa010_90m  A1a: Teacher's rating of child for age - gener...
# ..                ...                                                ...
# 846         c645_32wg                      Mums highest ed qualification
# 847    vitdtot_F7_84m                                Total Vitamin D, F7
# 848     vitdd3_F7_84m                           Vitamin D (25(OHD3)), F7
# 849        sa060r_90m                A5i: Child's stream for Mathematics
# 850  Helico_CIF31_31m              Helicobacter pylori status, 31mth CIF
#
#          corr         p_val      %mis  corr_imp     p_val_imp  \
# 0    1.000000  0.000000e+00  0.000000  1.000000  0.000000e+00
# 1    0.256065  3.728890e-44  0.140072  0.242957  5.390514e-46
# 2    0.223628  2.731790e-19  0.527894  0.156157  1.202148e-19
# 3    0.214249  6.479717e-31  0.146071  0.202335  3.863422e-32
# 4    0.209328  4.489150e-17  0.526995  0.146304  2.062000e-17
# ..        ...           ...       ...       ...           ...
# 846 -0.171721  4.066583e-21  0.107978 -0.163612  1.949678e-21
# 847 -0.174790  6.087091e-03  0.926515 -0.047565  6.014908e-03
# 848 -0.176972  5.472048e-03  0.926515 -0.048159  5.414129e-03
# 849 -0.211338  8.231674e-16  0.573785 -0.139685  5.396321e-16
# 850 -0.377964  1.767562e-02  0.988302 -0.040223  2.020202e-02
#
#      Diff_corr_and_corr_imp
# 0                  0.000000
# 1                  0.051190
# 2                  0.301711
# 3                  0.055606
# 4                  0.301080
# ..                      ...
# 846                0.047220
# 847                0.727873
# 848                0.727873
# 849                0.339046
# 850                0.893580
#
# [851 rows x 8 columns]

# %%
ax = sns.scatterplot(data=correlations, x = "%mis", y= "Diff_corr_and_corr_imp")
ax
# Out:
# <AxesSubplot:xlabel='%mis', ylabel='Diff_corr_and_corr_imp'>

# %%
ax.set_ylim(0, 1)
ax.figure

# %%
correlations['Diff_corr_and_corr_imp_dir'] = (correlations['corr_imp'] - correlations['corr']) / (correlations['corr'])

# %%
correlations
# Out:
#              features                                        description  \
# 0        12-18-dep-yn  SMFQ depression score above cutoff at any poin...
# 1        fddp130_120m      Depression Score at Focus 10 assessment: F10+
# 2           sa013_90m  A1d: Teacher's rating of child for age - gener...
# 3         ku710b_108m      DV: SDQ - Total difficulties score (prorated)
# 4           sa010_90m  A1a: Teacher's rating of child for age - gener...
# ..                ...                                                ...
# 846         c645_32wg                      Mums highest ed qualification
# 847    vitdtot_F7_84m                                Total Vitamin D, F7
# 848     vitdd3_F7_84m                           Vitamin D (25(OHD3)), F7
# 849        sa060r_90m                A5i: Child's stream for Mathematics
# 850  Helico_CIF31_31m              Helicobacter pylori status, 31mth CIF
#
#          corr         p_val      %mis  corr_imp     p_val_imp  \
# 0    1.000000  0.000000e+00  0.000000  1.000000  0.000000e+00
# 1    0.256065  3.728890e-44  0.140072  0.242957  5.390514e-46
# 2    0.223628  2.731790e-19  0.527894  0.156157  1.202148e-19
# 3    0.214249  6.479717e-31  0.146071  0.202335  3.863422e-32
# 4    0.209328  4.489150e-17  0.526995  0.146304  2.062000e-17
# ..        ...           ...       ...       ...           ...
# 846 -0.171721  4.066583e-21  0.107978 -0.163612  1.949678e-21
# 847 -0.174790  6.087091e-03  0.926515 -0.047565  6.014908e-03
# 848 -0.176972  5.472048e-03  0.926515 -0.048159  5.414129e-03
# 849 -0.211338  8.231674e-16  0.573785 -0.139685  5.396321e-16
# 850 -0.377964  1.767562e-02  0.988302 -0.040223  2.020202e-02
#
#      Diff_corr_and_corr_imp  Diff_corr_and_corr_imp_dir
# 0                  0.000000                    0.000000
# 1                  0.051190                   -0.051190
# 2                  0.301711                   -0.301711
# 3                  0.055606                   -0.055606
# 4                  0.301080                   -0.301080
# ..                      ...                         ...
# 846                0.047220                   -0.047220
# 847                0.727873                   -0.727873
# 848                0.727873                   -0.727873
# 849                0.339046                   -0.339046
# 850                0.893580                   -0.893580
#
# [851 rows x 9 columns]

# %%
ax = sns.scatterplot(data=correlations, x = "%mis", y= "Diff_corr_and_corr_imp_dir")
ax
# Out:
# <AxesSubplot:xlabel='%mis', ylabel='Diff_corr_and_corr_imp_dir'>

# %%
ax.set_ylim(-1, 1)
ax.figure

# %%
plt.tight_layout()
ax.figure.tight_layout()

ax.figure.savefig('./output/directional_correlations.svg', bbox_inches = 'tight')

# %%
correlations[correlations.Diff_corr_and_corr_imp_dir > 0]
# Out:
#            features                                        description  \
# 62         kz021_0m                                         Child sex
# 209        f252a_8m                              Return to work yes/no
# 244       k6264_61m                   F17c: Mother does voluntary work
# 332        f635r_8m                Mom has had paid jobs since CH born
# 333        kb066_6m                                CH admitted to HOSP
# 352       kl045_57m        A5a: Child admitted to hospital since age 3
# 366       kr812_91m  DV: DAWBA DSM-IV clinical diagnosis - Disrupti...
# 393       kr826_91m  DV: DAWBA DSM-IV clinical diagnosis - Anxiety ...
# 394     p2032r_110m  B33: Mother returned to work since the study c...
# 404       g340a_21m                  Partner started new job >CH88MTHs
# 410      kn1050_69m  A4a: Child was admitted to hospital in past 15...
# 415       j325a_47m                   MUM Got Married> CH 30 MTHs  y/n
# 417       g332a_21m               Mum returned to work >CH8MTHs yes/no
# 448  widowed8wg_8wg                                        Mom widowed
# 454     p2000r_110m  B1: Husband/partner died since the study child...
# 465  widowed33m_33m                                        Mom widowed
# 475  widowed85m_85m                                        Mom widowed
# 482  widowed97m_97m                                        Mom widowed
# 520  widowed21m_21m                                        Mom widowed
# 551       c800_32wg                           Mother ethnic background
# 565    widowed8m_8m                                        Mom widowed
# 611    reprodpb_97m  Boy born with scrotum or penis problems (girls...
#
#          corr         p_val      %mis  corr_imp     p_val_imp  \
# 62   0.116827  1.349178e-11  0.000900  0.117260  1.109061e-11
# 209  0.051624  4.728394e-03  0.102280  0.069105  6.511737e-05
# 244  0.040165  4.395694e-02  0.245351  0.066924  1.101246e-04
# 332  0.017820  3.309867e-01  0.106779  0.040552  1.920238e-02
# 333  0.017605  3.345934e-01  0.098380  0.025812  1.362000e-01
# 352  0.014053  4.526485e-01  0.142771  0.028586  9.887696e-02
# 366  0.011393  5.487142e-01  0.168266  0.015399  3.740879e-01
# 393  0.004910  7.956637e-01  0.164967  0.011118  5.210340e-01
# 394  0.004692  8.043625e-01  0.163167  0.033037  5.647146e-02
# 404  0.002562  8.897194e-01  0.120876  0.016944  3.280567e-01
# 410  0.001563  9.344215e-01  0.167666  0.016699  3.350753e-01
# 415  0.000103  9.955823e-01  0.140372  0.005942  7.316184e-01
# 417  0.000063  9.972710e-01  0.120876  0.016288  3.471045e-01
# 448 -0.007118  6.916660e-01  0.068086 -0.007316  6.728063e-01
# 454 -0.008388  6.562494e-01  0.154769 -0.010350  5.502342e-01
# 465 -0.011370  5.423835e-01  0.138272 -0.012680  4.642274e-01
# 475 -0.013267  4.840160e-01  0.164667 -0.016380  3.444153e-01
# 482 -0.014298  4.513486e-01  0.167067 -0.017948  3.001816e-01
# 520 -0.019851  2.853205e-01  0.130474 -0.020537  2.358266e-01
# 551 -0.025516  1.574681e-01  0.078884 -0.027110  1.175770e-01
# 565 -0.027376  1.350835e-01  0.105879 -0.027451  1.130238e-01
# 611 -0.037070  4.419607e-02  0.116077 -0.037944  2.845813e-02
#
#      Diff_corr_and_corr_imp  Diff_corr_and_corr_imp_dir
# 62                 0.003710                    0.003710
# 209                0.338616                    0.338616
# 244                0.666206                    0.666206
# 332                1.275627                    1.275627
# 333                0.466171                    0.466171
# 352                1.034131                    1.034131
# 366                0.351596                    0.351596
# 393                1.264322                    1.264322
# 394                6.041630                    6.041630
# 404                5.612687                    5.612687
# 410                9.686253                    9.686253
# 415               56.428137                   56.428137
# 417              256.712886                  256.712886
# 448                0.027895                    0.027895
# 454                0.233874                    0.233874
# 465                0.115168                    0.115168
# 475                0.234607                    0.234607
# 482                0.255295                    0.255295
# 520                0.034564                    0.034564
# 551                0.062471                    0.062471
# 565                0.002733                    0.002733
# 611                0.023592                    0.023592

# %%
correlations.to_csv('./output/vars_sorted_dir.csv')

# %%
preprocessed_with_temporal = pd.read_csv('./output/preprocessed_data_with_temporal.txt')

# %%
len(preprocessed_with_temporal['timestamp'].unique())
# Out:
# 54

# %%
preprocessed_with_temporal['timestamp'].unique()
# Out:
# array(['8wg', '15wg', '18wg', '20wg', '32wg', '0m', '4w', '1m', '8w',
#        '6m', '8m', '18m', '21m', '24m', '42m', '47m', '61m', '69m', '84m',
#        '90m', '91m', '97m', '120m', '122m', '192m', '12wg', '25wg', '30m',
#        '33m', '38m', '57m', '73m', '81m', '85m', '96m', '103m', '108m',
#        '115m', '116m', '127m', '144m', '162m', '204m', '110m', '216m',
#        '13wg', '12m', '25m', '31m', '37m', '43m', '49m', '102m', '4m'],
#       dtype=object)
